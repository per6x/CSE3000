# %%
# !pip install pandas
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 10.7/10.7 MB 15.0 MB/s eta 0:00:0000:0100:01
# ...
#   Using cached pytz-2023.3-py2.py3-none-any.whl (502 kB)
# ...
#   Using cached tzdata-2023.3-py2.py3-none-any.whl (341 kB)
# ...

# %%
import pandas as pd

# %% [markdown]
# ### Load metadata of the datasets

# %%
# load the metadata of 2 datasets
meta_a = pd.read_csv("PRJNA757365/metadata.csv",sep=";")
meta_b = pd.read_csv("PRJNA904924/metadata.csv",sep=";")

# %% [markdown]
# ### Review the columns

# %%
col_a = meta_a.columns
col_b = meta_b.columns
print(col_a, col_b, sep="\n")
print(col_a.difference(col_b))
print(col_b.difference(col_a))
# Out:
# Index(['Run', 'Assay Type', 'AvgSpotLen', 'Bases', 'BioProject', 'BioSample',
#        'BioSampleModel', 'Bytes', 'Center Name', 'Collection_Date', 'Consent',
#        'DATASTORE filetype', 'DATASTORE provider', 'DATASTORE region',
#        'Experiment', 'geo_loc_name_country', 'geo_loc_name_country_continent',
#        'geo_loc_name', 'HOST', 'Instrument', 'Isolation_Source', 'Lat_Lon',
#        'Library Name', 'LibraryLayout', 'LibrarySelection', 'LibrarySource',
#        'Organism', 'Platform', 'ReleaseDate', 'create_date', 'version',
#        'Sample Name', 'SRA Study', 'Class'],
#       dtype='object')
# Index(['Run', 'Assay Type', 'AvgSpotLen', 'Bases', 'BioProject', 'BioSample',
#        'BioSampleModel', 'Bytes', 'Center Name', 'Collection_Date', 'Consent',
#        'DATASTORE filetype', 'DATASTORE provider', 'DATASTORE region',
#        'Experiment', 'geo_loc_name_country', 'geo_loc_name_country_continent',
# ...

# %%
col_a.difference(col_b)
# Out:
# Index([], dtype='object')

# %%
col_b.difference(col_a)
# Out:
# Index(['Age', 'Sex', 'samp_collect_device', 'samp_mat_process', 'samp_size'], dtype='object')

# %%
meta_a = meta_a[meta_a["Sample Name"].str[-2:] != "D2"]
meta_a
# Out:
#             Run Assay Type  AvgSpotLen       Bases   BioProject     BioSample
# 3   SRR15595350        WGS         302  3170046888  PRJNA757365  SAMN20959281  \
# 12  SRR15595341        WGS         302  1954220256  PRJNA757365  SAMN20959298
# 19  SRR15595334        WGS         302  5246573218  PRJNA757365  SAMN20959258
# 20  SRR15595333        WGS         302  4952607324  PRJNA757365  SAMN20959259
# 22  SRR15595331        WGS         302  4458551632  PRJNA757365  SAMN20959260
# 23  SRR15595330        WGS         302  2433503920  PRJNA757365  SAMN20959299
# 34  SRR15595319        WGS         302  1792452446  PRJNA757365  SAMN20959278
# 37  SRR15595315        WGS         302  1586737294  PRJNA757365  SAMN20959282
# 38  SRR15595313        WGS         302  4100095450  PRJNA757365  SAMN20959301
# 39  SRR15595311        WGS         302  1918777838  PRJNA757365  SAMN20959283
# 40  SRR15595309        WGS         302  1546469520  PRJNA757365  SAMN20959284
# ...

# %%
metadata = pd.concat([meta_a, meta_b], axis=0, ignore_index=True)
metadata
# Out:
#              Run Assay Type  AvgSpotLen        Bases   BioProject
# 0    SRR15595350        WGS         302   3170046888  PRJNA757365  \
# 1    SRR15595341        WGS         302   1954220256  PRJNA757365
# 2    SRR15595334        WGS         302   5246573218  PRJNA757365
# 3    SRR15595333        WGS         302   4952607324  PRJNA757365
# 4    SRR15595331        WGS         302   4458551632  PRJNA757365
# ..           ...        ...         ...          ...          ...
# 170  SRR22402268        WGS         297  10759128468  PRJNA904924
# 171  SRR22402267        WGS         297  19362472514  PRJNA904924
# 172  SRR22402325        WGS         297  24394619060  PRJNA904924
# 173  SRR22402333        WGS         296  10480225436  PRJNA904924
# 174  SRR22402329        WGS         299   6218800901  PRJNA904924
#
#         BioSample               BioSampleModel       Bytes
# 0    SAMN20959281  Metagenome or environmental  1357168858  \
# ...

# %%
metadata
# Out:
#              Run Assay Type  AvgSpotLen        Bases   BioProject
# 0    SRR15595350        WGS         302   3170046888  PRJNA757365  \
# 1    SRR15595341        WGS         302   1954220256  PRJNA757365
# 2    SRR15595334        WGS         302   5246573218  PRJNA757365
# 3    SRR15595333        WGS         302   4952607324  PRJNA757365
# 4    SRR15595331        WGS         302   4458551632  PRJNA757365
# ..           ...        ...         ...          ...          ...
# 170  SRR22402268        WGS         297  10759128468  PRJNA904924
# 171  SRR22402267        WGS         297  19362472514  PRJNA904924
# 172  SRR22402325        WGS         297  24394619060  PRJNA904924
# 173  SRR22402333        WGS         296  10480225436  PRJNA904924
# 174  SRR22402329        WGS         299   6218800901  PRJNA904924
#
#         BioSample               BioSampleModel       Bytes
# 0    SAMN20959281  Metagenome or environmental  1357168858  \
# ...

# %%
metadata.to_csv("metadata_v2.csv", sep=";")
